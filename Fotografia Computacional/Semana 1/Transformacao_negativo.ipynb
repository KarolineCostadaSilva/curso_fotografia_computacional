# %% [markdown]
# <a href="https://colab.research.google.com/github/KarolineCostadaSilva/curso_fotografia_computacional/blob/main/Semana%201/Transformacao_negativo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Operações de tranformação de imagens: negativo
#
# #Referência: https://opencv24-python-tutorials.readthedocs.io/en/latest/py_tutorials/py_imgproc/py_geometric_transformations/py_geometric_transformations.html

# %%
import os
if os.path.isdir("imgcourse"):
  print("Diretório já existe!")
else:
  # !git clone https://github.com/mhsacampos/imgcourse
# Out:
# Diretório já existe!

# %% [markdown]
# #A partir da célula abaixo começa, de fato, a programação Python + OpenCV (cv2)

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np


im_path = "./imgcourse/Cin.jpg"
image = cv2.imread(im_path)

cv2_imshow(image)

print("\n\n")

photos_bgr_ = list()
photos_bgr_.append(image)
negatives_images = list()
for photo in photos_bgr_:
  #  neg_image = np.full(photo.shape, max_pix) # InCorreto !!!
   neg_image = np.full(photo.shape, 255) # Correto !!!
   negatives_images.append(neg_image - photo)
   cv2_imshow(neg_image - photo)
# Out:
# <PIL.Image.Image image mode=RGB size=640x360>
# <PIL.Image.Image image mode=RGB size=640x360>
